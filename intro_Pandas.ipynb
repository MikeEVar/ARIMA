# %% [markdown]
# <a href="https://colab.research.google.com/github/MikeEVar/ARIMA/blob/master/intro_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas: Python Data Analysis Library
import pandas as pd #biblioteca/librería

# %%
lista=[False,False]
True in lista
# Out:
# False

# %%
#read_csv sirve para leer archivo tipo texto "plano"
#e.g. .txt, .dat, .tsv, .csv
db=pd.read_csv('file1.csv')
#DataFrame

# %%
type(db)
# Out:
# pandas.core.frame.DataFrame

# %%
db
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
db.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
db.tail(10)
# Out:
#      Customer   ST GENDER Education Customer Lifetime Value  Income  \
# 3998      NaN  NaN    NaN       NaN                     NaN     NaN
# 3999      NaN  NaN    NaN       NaN                     NaN     NaN
# 4000      NaN  NaN    NaN       NaN                     NaN     NaN
# 4001      NaN  NaN    NaN       NaN                     NaN     NaN
# 4002      NaN  NaN    NaN       NaN                     NaN     NaN
# 4003      NaN  NaN    NaN       NaN                     NaN     NaN
# 4004      NaN  NaN    NaN       NaN                     NaN     NaN
# 4005      NaN  NaN    NaN       NaN                     NaN     NaN
# 4006      NaN  NaN    NaN       NaN                     NaN     NaN
# 4007      NaN  NaN    NaN       NaN                     NaN     NaN
#
#       Monthly Premium Auto Number of Open Complaints Policy Type  \
# 3998                   NaN                       NaN         NaN
# 3999                   NaN                       NaN         NaN
# ...

# %%
#Las propiedades en los objetos en Python, no llevan ()
#Los métodos/funciones sí deben llevar ()
db.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
db['ST'][0]
# Out:
# 'Washington'

# %%
db.index
# Out:
# RangeIndex(start=0, stop=4008, step=1)

# %%
#para traerme toda una columna de la base de datos
db['ST']
# Out:
# 0       Washington
# 1          Arizona
# 2           Nevada
# 3       California
# 4       Washington
#            ...
# 4003           NaN
# 4004           NaN
# 4005           NaN
# 4006           NaN
# 4007           NaN
# Name: ST, Length: 4008, dtype: object

# %%
#Para traerme un valor en particular de una columna
db['ST'][2]
# Out:
# 'Nevada'

# %%
#Si me quiero traer del registo 10 al 15 de la columan ST
db['ST'][10:15]
# Out:
# 10    California
# 11    California
# 12    California
# 13       Arizona
# 14    California
# Name: ST, dtype: object

# %%
w=db.shape[1]

# %%
# Out:
# 26

# %%
db.describe()
# Out:
#              Income  Monthly Premium Auto  Total Claim Amount
# count   1071.000000           1071.000000         1071.000000
# mean   39295.701214            193.234360          404.986909
# std    30469.427060           1601.190369          293.027260
# min        0.000000             61.000000            0.382107
# 25%    14072.000000             68.000000          202.157702
# 50%    36234.000000             83.000000          354.729129
# 75%    64631.000000            109.500000          532.800000
# max    99960.000000          35354.000000         2893.239678

# %%
#Vamos a homogeneiza el texto de las columnas, todo a minúsculas
cols=[]
for i in range (len(db.columns)):
  cols.append(db.columns[i].lower())
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer lifetime value',
#  'income',
#  'monthly premium auto',
#  'number of open complaints',
#  'policy type',
#  'vehicle class',
#  'total claim amount']

# %%
db.columns=cols

# %%
db.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
lista4=[1,2,3]

# %%
lista4.append("El pepe")

# %%
lista4
# Out:
# [1, 2, 3, 4, 4, 'El pepe']

# %%
db.columns[0].lower()
# Out:
# 'customer'

# %%
db.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
db['incomeX2']=db['income']*2

# %%
db
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
db=db.drop('incomeX2',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-5d2018ac7ac7> in <module>
# ----> 1 db=db.drop('incomeX2',axis=1)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
db
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
db['gender'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
db['gender'].value_counts()
# Out:
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: gender, dtype: int64

# %%
for i in range(len(db)):
  if(db['gender'][i]=="Femal"):
    print("el registro",i,"tiene mal escrito Female")
# Out:
# el registro 154 tiene mal escrito Female
# el registro 213 tiene mal escrito Female
# el registro 215 tiene mal escrito Female
# el registro 217 tiene mal escrito Female
# el registro 218 tiene mal escrito Female
# el registro 220 tiene mal escrito Female
# el registro 224 tiene mal escrito Female
# el registro 225 tiene mal escrito Female
# el registro 227 tiene mal escrito Female
# el registro 230 tiene mal escrito Female
# el registro 233 tiene mal escrito Female
# el registro 236 tiene mal escrito Female
# el registro 239 tiene mal escrito Female
# el registro 240 tiene mal escrito Female
# el registro 241 tiene mal escrito Female
# el registro 242 tiene mal escrito Female
# el registro 244 tiene mal escrito Female

# %%
db[(db['gender']=="Femal") & (db['st']=="Oregon") &(db['income']<50000)]

# %%
sum(db['gender'].isnull())
# Out:
# 3054

# %%
#| es pipeline
db[ ((db['gender']=="Femal") |(db['gender']=="female")) & (db['education']=='Bachelor')]
# Out:
#     customer          st  gender education customer lifetime value   income  \
# 154  YM50253  California   Femal  Bachelor              294615.37%  89270.0
# 220  LK60013      Oregon   Femal  Bachelor              596955.30%  97431.0
# 230  XV84099     Arizona   Femal  Bachelor              550413.90%      0.0
# 233  HI14283      Oregon   Femal  Bachelor              565703.16%      0.0
# 236  TX17484        Cali   Femal  Bachelor             1518227.98%  53863.0
# 239  DE55857          WA   Femal  Bachelor              246544.49%  64997.0
# 297  MF82000          WA  female  Bachelor              236534.86%      0.0
# 345  RZ13254      Nevada  female  Bachelor              756282.40%      0.0
# 348  KU84464      Nevada  female  Bachelor              942256.79%  47272.0
# 361  QD34785     Arizona  female  Bachelor              567805.02%      0.0
# 362  RO26085  California  female  Bachelor             1210120.88%      0.0
# ...

# %%
db.iloc[377:400]
# Out:
#     customer          st  gender             education  \
# 377  FG16766  California  female              Bachelor
# 378  NV55438      Nevada  female  High School or Below
# 379  RM10880  California  female               College
# 380  GL56175     Arizona       M               College
# 381  UK52289     Arizona  female              Bachelor
# 382  OT85112  Washington       M               College
# 383  BC62782     Arizona       F               College
# 384  TI19722  Washington       M                Doctor
# 385  JP30654      Oregon       F               College
# 386  UM45563  Washington       M              Bachelor
# 387  EN60878      Oregon       M              Bachelor
# 388  JF36291  California       M               College
# 389  BK59444  California       F                Master
# 390  MK70700  California       M                Master
# 391  IW71076  California       M              Bachelor
# 392  AP98768  California       F               College
# ...

# %%
columna_extra=db['income']*3

# %%
columna_extra
# Out:
# 0            0.0
# 1            0.0
# 2       146301.0
# 3            0.0
# 4       109071.0
#           ...
# 4003         NaN
# 4004         NaN
# 4005         NaN
# 4006         NaN
# 4007         NaN
# Name: income, Length: 4008, dtype: float64

# %%
db2=pd.concat([db,db],axis=1)

# %%
db2
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income monthly premium auto  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
import random
nombres=["André","Diego","Emi","Irina","JC","Maya","Moni","Pedro","Raúl","Ara","Thi"]
equipo1=random.sample(nombres,3)
print("El equipo 1 son", equipo1)
nombres.remove(equipo1[0])
nombres.remove(equipo1[1])
nombres.remove(equipo1[2])
equipo2=random.sample(nombres,3)
print("El equipo 2 son", equipo2)
nombres.remove(equipo2[0])
nombres.remove(equipo2[1])
nombres.remove(equipo2[2])
equipo3=random.sample(nombres,3)
print("El equipo 3 son", equipo3)
nombres.remove(equipo3[0])
nombres.remove(equipo3[1])
nombres.remove(equipo3[2])
print("El equipo 4 son", nombres)
# Out:
# El equipo 1 son ['Emi', 'Pedro', 'Moni']
# El equipo 2 son ['Irina', 'Diego', 'JC']
# El equipo 3 son ['Maya', 'André', 'Raúl']
# El equipo 4 son ['Ara', 'Thi']

# %%
file1 = pd.read_csv("file1.txt")
file2 = pd.read_csv("file2.txt", sep = '\t')

# %%
column_names = file1.columns
data = pd.DataFrame(columns=column_names)
data = pd.concat([data,file1,file2], axis=0)
data
# Out:
#      CONTROLN STATE  GENDER      HV1  IC1    IC4 HVP1    IC5 POBC1 POBC2  \
# 0       44060    FL       M   AAA896  392  520.0    7  21975     6    16
# 1       96093    IL       M   537.00  365  473.0    0  19387     1    89
# 2       43333    FL       F   725.00  301  436.0    3  18837    11    17
# 3       21885    NC       M  AAA1095  401  413.0    7  14014     1    74
# 4      190108    FL       F   995.00  252  348.0    0  17991     5     6
# ...       ...   ...     ...      ...  ...    ...  ...    ...   ...   ...
# 1010   161838    CA       F     1953  304  380.0   47  13811    25    43
# 1011   161838    CA       F     1953  304  380.0   47  13811    25    43
# 1012   138311    AZ  Female     1708  437  684.0   36  29098     7    19
# 1013   123469    TX       M      561  493  540.0    1  16623     5    68
# 1014   135341    AZ  Female      700  205  295.0    0  12713     9    12
#
#         IC2  IC3    AVGGIFT TCODE   DOB DOMAIN  TARGET_D
# ...

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
CONTROLNabcSTATabcGENDER6asbHV1	IC1	IC4	HVP1	IC5	POBC1	POBC2	IC2	IC3	AVGGIFT	TCODE	DOB	DOMAIN	TARGET_D
1,000,000  	CA    	M	    3200	310	343	83	17224	31	32  	311	333	3.106060606	1	0  	U1     	4
